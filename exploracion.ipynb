# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
inf_dem = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_01_INF_DEMOGRAFICA.csv")
inf_dem.head(15)
# Out:
#                     ENT      ZONA     HOGARES   HABITANTES
# 0              Nacional     Rural   8,608,589   31,503,312
# 1              Nacional    Urbana  28,983,284   97,205,972
# 2              Nacional  Nacional  37,591,873  128,709,284
# 3        Aguascalientes     Rural     100,461      386,130
# 4        Aguascalientes    Urbana     312,857    1,095,628
# 5        Aguascalientes  Nacional     413,318    1,481,758
# 6       Baja California     Rural     120,964      400,002
# 7       Baja California    Urbana   1,088,352    3,416,397
# 8       Baja California  Nacional   1,209,316    3,816,399
# 9   Baja California Sur     Rural      56,689      160,948
# 10  Baja California Sur    Urbana     220,426      678,883
# 11  Baja California Sur  Nacional     277,115      839,831
# 12             Campeche     Rural      67,460      264,004
# 13             Campeche    Urbana     198,466      685,284
# 14             Campeche  Nacional     265,926      949,288

# %%
int_sm_edad = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_02_INTERNET_SMARTPHONE_EDAD.csv")
int_sm_edad.head(15)
# Out:
#                ENT    SEXO    GPO_EDAD  PORCENTAJE_INT_EDAD  \
# 0         Nacional   Mujer   6-11 años                70.98
# 1         Nacional   Mujer  12-17 años                92.39
# 2         Nacional   Mujer  18-24 años                93.86
# 3         Nacional   Mujer  25-34 años                92.51
# 4         Nacional   Mujer  35-44 años                86.66
# 5         Nacional   Mujer  45-54 años                79.56
# 6         Nacional   Mujer    55 o más                46.38
# 7         Nacional  Hombre   6-11 años                73.10
# 8         Nacional  Hombre  12-17 años                92.46
# 9         Nacional  Hombre  18-24 años                96.27
# 10        Nacional  Hombre  25-34 años                93.06
# 11        Nacional  Hombre  35-44 años                87.64
# 12        Nacional  Hombre  45-54 años                75.77
# 13        Nacional  Hombre    55 o más                48.96
# 14  Aguascalientes   Mujer   6-11 años                91.55
#
# ...

# %%
int_sm_edu = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_02_INTERNET_SMARTPHONE_EDUCACION.csv")
int_sm_edu.head(15)
# Out:
#                ENT    SEXO      NIVEL_ED  PORCENTAJE_INT_EDUC  \
# 0         Nacional   Mujer       Ninguno                27.26
# 1         Nacional   Mujer      Primaria                57.61
# 2         Nacional   Mujer    Secundaria                85.09
# 3         Nacional   Mujer  Preparatoria                94.82
# 4         Nacional   Mujer  Licenciatura                98.04
# 5         Nacional   Mujer      Posgrado                99.63
# 6         Nacional  Hombre       Ninguno                36.93
# 7         Nacional  Hombre      Primaria                58.49
# 8         Nacional  Hombre    Secundaria                85.75
# 9         Nacional  Hombre  Preparatoria                94.20
# 10        Nacional  Hombre  Licenciatura                97.19
# 11        Nacional  Hombre      Posgrado                99.03
# 12  Aguascalientes   Mujer       Ninguno                54.63
# 13  Aguascalientes   Mujer      Primaria                72.76
# ...

# %%
int_sm_ocup = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_02_INTERNET_SMARTPHONE_OCUPACION.csv")
int_sm_ocup.head(15)
# Out:
#       OCUPACION             ENT    SEXO  PORCENTAJE_SMART_OCUP  \
# 0   No contestó        Nacional   Mujer                  34.86
# 1       Trabaja        Nacional   Mujer                  90.72
# 2    No Trabaja        Nacional   Mujer                  66.40
# 3    Estudiante        Nacional   Mujer                  88.92
# 4         Hogar        Nacional   Mujer                  67.37
# 5   No contestó        Nacional  Hombre                  35.71
# 6       Trabaja        Nacional  Hombre                  83.25
# 7    No Trabaja        Nacional  Hombre                  60.72
# 8    Estudiante        Nacional  Hombre                  87.16
# 9         Hogar        Nacional  Hombre                  55.12
# 10  No contestó  Aguascalientes   Mujer                  27.00
# 11      Trabaja  Aguascalientes   Mujer                  92.88
# 12   No Trabaja  Aguascalientes   Mujer                  72.29
# 13   Estudiante  Aguascalientes   Mujer                  89.57
# ...

# %%
servicios = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_03_SERVICIOS.csv")
servicios.head(15)
# Out:
#                 ENTIDAD         SERVICIO  LINEAS_ACCESOS
# 0        Aguascalientes    Internet fijo              73
# 1        Aguascalientes   Internet móvil              91
# 2        Aguascalientes   TV Restringida              64
# 3        Aguascalientes   Telefonía fija              53
# 4        Aguascalientes  Telefonía móvil             110
# 5       Baja California    Internet fijo              97
# 6       Baja California   Internet móvil             110
# 7       Baja California   TV Restringida              76
# 8       Baja California   Telefonía fija              90
# 9       Baja California  Telefonía móvil             121
# 10  Baja California Sur    Internet fijo              80
# 11  Baja California Sur   Internet móvil             103
# 12  Baja California Sur   TV Restringida              77
# 13  Baja California Sur   Telefonía fija              67
# 14  Baja California Sur  Telefonía móvil             118

# %%
uni_econ = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_04_UNIDADES_ECONOMICAS.csv")
uni_econ.head(15)
# Out:
#            ENTIDAD NÚMERO DE PERSONAS  \
# 0         Nacional             0 a 10
# 1         Nacional             0 a 10
# 2         Nacional             0 a 10
# 3         Nacional             0 a 10
# 4         Nacional             0 a 10
# 5         Nacional             0 a 10
# 6         Nacional             0 a 10
# 7         Nacional             0 a 10
# 8         Nacional             0 a 10
# 9         Nacional             0 a 10
# 10        Nacional             0 a 10
# 11        Nacional             0 a 10
# 12        Nacional             0 a 10
# 13  Aguascalientes             0 a 10
# 14  Aguascalientes             0 a 10
#
#                                                   USO        VALOR   \
# 0                                Unidades económicas   4,536,341.00
# 1                               Emplearon computadora            20
# 2                                  Emplearon Internet          17.4
# 3                               Operaciones bancarias          52.9
# ...

# %%
gasto_tel = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_05_GASTO_TELECOMUNICACIONES.csv")
gasto_tel.head(15)
# Out:
#              ENTIDAD  DECIL_ING  GASTO_PM_FIJAS  PORCENTAJE_GASTO_FIJAS  \
# 0     Aguascalientes          1          383.21                    6.17
# 1     Aguascalientes          2          390.44                    4.12
# 2     Aguascalientes          3          421.46                    3.51
# 3     Aguascalientes          4          451.33                    3.07
# 4     Aguascalientes          5          491.57                    2.77
# 5     Aguascalientes          6          490.53                    2.35
# 6     Aguascalientes          7          511.57                    2.05
# 7     Aguascalientes          8          565.88                    1.86
# 8     Aguascalientes          9          567.28                    1.39
# 9     Aguascalientes         10          692.03                    0.84
# 10  Baja California           1          419.57                    5.62
# 11  Baja California           2          484.78                    4.03
# ...

# %%
disp_tic = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_06_DISPONIBILIDAD_TIC.csv")
disp_tic.head(15)
# Out:
#                ENT    ZONA           EQUIPO  PORCENTAJE
# 0         Nacional   Rural      Computadora       20.46
# 1         Nacional   Rural            Radio       42.37
# 2         Nacional   Rural     TV analógica       23.94
# 3         Nacional   Rural       TV digital       66.90
# 4         Nacional   Rural  Telefonía móvil       87.15
# 5         Nacional  Urbana      Computadora       50.86
# 6         Nacional  Urbana            Radio       49.02
# 7         Nacional  Urbana     TV analógica       21.78
# 8         Nacional  Urbana       TV digital       83.22
# 9         Nacional  Urbana  Telefonía móvil       95.80
# 10  Aguascalientes   Rural      Computadora       35.64
# 11  Aguascalientes   Rural            Radio       60.73
# 12  Aguascalientes   Rural     TV analógica       28.93
# 13  Aguascalientes   Rural       TV digital       81.63
# 14  Aguascalientes   Rural   Telefonía fija       92.29

# %%
dist_serv_fij = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_06_DISTRIBUCION_SERVICIOS_FIJOS.csv")
dist_serv_fij.head(15)
# Out:
#                ENT    ZONA   TIPO_CONTRATO                         SERVICIO  \
# 0   Aguascalientes   Rural     Un servicio                   Telefonía fija
# 1   Aguascalientes   Rural     Un servicio                         Internet
# 2   Aguascalientes   Rural     Un servicio                   TV restringida
# 3   Aguascalientes   Rural     Un servicio                            Total
# 4   Aguascalientes   Rural   Dos servicios        Telefonía fija e internet
# 5   Aguascalientes   Rural   Dos servicios        TV restringida e internet
# 6   Aguascalientes   Rural   Dos servicios  TV restringida y telefonía fija
# 7   Aguascalientes   Rural   Dos servicios                            Total
# 8   Aguascalientes   Rural  Tres servicios                            Total
# 9   Aguascalientes  Urbana     Un servicio                   Telefonía fija
# 10  Aguascalientes  Urbana     Un servicio                         Internet
# ...

# %%
razones_no_int = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_07_RAZONES_NO_USO_INT.csv")
razones_no_int.head(15)
# Out:
#                 ENT                RAZONES  PORCENTAJE
# 0    Aguascalientes        No tiene acceso       13.32
# 1    Aguascalientes     No sabe utilizarlo       46.38
# 2    Aguascalientes     No tiene necesidad       27.20
# 3    Aguascalientes      Falta de recursos        8.21
# 4    Aguascalientes       Por discapacidad        3.14
# 5    Aguascalientes         Por privacidad        0.36
# 6    Aguascalientes  No le permiten usarlo        1.26
# 7    Aguascalientes             Otra razón        0.14
# 8   Baja California        No tiene acceso       12.04
# 9   Baja California     No sabe utilizarlo       46.75
# 10  Baja California     No tiene necesidad       27.35
# 11  Baja California      Falta de recursos        8.86
# 12  Baja California       Por discapacidad        1.65
# 13  Baja California         Por privacidad        0.68
# 14  Baja California  No le permiten usarlo        2.67

# %%
act_int = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_08_ACTIVIDADES_POR_INTERNET.csv")
act_int.head(15)
# Out:
#                ENT                  ACTIVIDADES  PORCENTAJE
# 0         Nacional                       Ventas       11.31
# 1         Nacional        Operaciones bancarias       24.38
# 2         Nacional                        Pagos       26.87
# 3         Nacional                 Capacitación       83.34
# 4         Nacional                      Compras       30.58
# 5         Nacional  Interacción con el gobierno       39.07
# 6         Nacional               Redes sociales       90.58
# 7         Nacional           Buscar información       89.29
# 8         Nacional                 Comunicación       93.78
# 9         Nacional              Entretenimiento       89.58
# 10  Aguascalientes                       Ventas       11.21
# 11  Aguascalientes        Operaciones bancarias       25.92
# 12  Aguascalientes                        Pagos       26.70
# 13  Aguascalientes                 Capacitación       82.20
# 14  Aguascalientes                      Compras       32.14

# %%
disp_radio = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_09_DISPOSITIVO_RADIO.csv")
disp_radio.head(15)
# Out:
#                     ENT          DISPOSITIVO  PORCENTAJE
# 0        Aguascalientes              Estereo       36.20
# 1        Aguascalientes  Radio del automóvil       33.55
# 2        Aguascalientes       Radio portátil       18.25
# 3        Aguascalientes     Teléfono celular       10.08
# 4        Aguascalientes               Tablet         NaN
# 5        Aguascalientes          Computadora        0.29
# 6        Aguascalientes                 Otro        1.63
# 7       Baja California              Estereo       21.12
# 8       Baja California  Radio del automóvil       68.28
# 9       Baja California       Radio portátil        6.10
# 10      Baja California     Teléfono celular        3.07
# 11      Baja California               Tablet         NaN
# 12      Baja California          Computadora        0.24
# 13      Baja California                 Otro        1.19
# 14  Baja California Sur              Estereo       29.22

# %%
lug_radio = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_09_LUGAR_RADIO.csv")
lug_radio.head(15)
# Out:
#                     ENT               LUGAR  PORCENTAJE
# 0        Aguascalientes               Hogar       51.88
# 1        Aguascalientes           Automóvil       32.41
# 2        Aguascalientes  Transporte público        1.47
# 3        Aguascalientes             Trabajo       13.62
# 4        Aguascalientes                Otro        0.62
# 5       Baja California               Hogar       24.23
# 6       Baja California           Automóvil       66.09
# 7       Baja California  Transporte público        4.06
# 8       Baja California             Trabajo        5.25
# 9       Baja California                Otro        0.38
# 10  Baja California Sur               Hogar       37.44
# 11  Baja California Sur           Automóvil       50.60
# 12  Baja California Sur  Transporte público        1.67
# 13  Baja California Sur             Trabajo        8.01
# 14  Baja California Sur                Otro        2.27

# %%
razones_no_rad = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_09_RAZONES_NO_RADIO.csv")
razones_no_rad.head(15)
# Out:
#                     ENT                    RAZONES  PORCENTAJE
# 0        Aguascalientes             No le interesa       82.47
# 1        Aguascalientes  No cuenta con dispositivo       16.26
# 2        Aguascalientes    No hay cobertura de red        0.19
# 3        Aguascalientes           Por discapacidad        0.92
# 4        Aguascalientes                 Otra razón        0.17
# 5       Baja California             No le interesa       79.79
# 6       Baja California  No cuenta con dispositivo       17.42
# 7       Baja California    No hay cobertura de red        1.64
# 8       Baja California           Por discapacidad        0.46
# 9       Baja California                 Otra razón        0.69
# 10  Baja California Sur             No le interesa       67.66
# 11  Baja California Sur  No cuenta con dispositivo       25.62
# 12  Baja California Sur    No hay cobertura de red        4.67
# 13  Baja California Sur           Por discapacidad        0.85
# ...

# %%
razones_no_tva = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_09_RAZONES_NO_TVA.csv")
razones_no_tva.head(15)
# Out:
#                     ENT                      RAZONES  PORCENTAJE
# 0        Aguascalientes               No le interesa       87.98
# 1        Aguascalientes  No cuenta con aparato de TV        8.43
# 2        Aguascalientes      No hay cobertura de red        2.44
# 3        Aguascalientes             Por discapacidad        0.90
# 4        Aguascalientes                   Otra razón        0.26
# 5       Baja California               No le interesa       89.96
# 6       Baja California  No cuenta con aparato de TV        6.27
# 7       Baja California      No hay cobertura de red        3.16
# 8       Baja California             Por discapacidad        0.27
# 9       Baja California                   Otra razón        0.33
# 10  Baja California Sur               No le interesa       80.01
# 11  Baja California Sur  No cuenta con aparato de TV       15.06
# 12  Baja California Sur      No hay cobertura de red        2.99
# ...

# %%
conc_radio_tdt = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_10_CONCESIONES_RADIO_Y_TDT.csv")
conc_radio_tdt.head(15)
# Out:
#            ENTIDAD              CONCESION BANDA  ESTACIONES
# 0   Aguascalientes            Comerciales   A.M         1.0
# 1   Aguascalientes            Comerciales   F.M        16.0
# 2   Aguascalientes            Comerciales   TDT         5.0
# 3   Aguascalientes               Públicas   A.M         NaN
# 4   Aguascalientes               Públicas   F.M         3.0
# 5   Aguascalientes               Públicas   TDT         3.0
# 6   Aguascalientes               Sociales   A.M         NaN
# 7   Aguascalientes               Sociales   F.M         4.0
# 8   Aguascalientes               Sociales   TDT         1.0
# 9   Aguascalientes  Sociales Comunitarias   A.M         NaN
# 10  Aguascalientes  Sociales Comunitarias   F.M         1.0
# 11  Aguascalientes  Sociales Comunitarias   TDT         NaN
# 12  Aguascalientes     Sociales Indígenas   A.M         NaN
# 13  Aguascalientes     Sociales Indígenas   F.M         NaN
# 14  Aguascalientes     Sociales Indígenas   TDT         NaN

# %%
dist_serv_fij2 = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_11_DISTRIBUCION_SERVICIOS_FIJOS .csv")
dist_serv_fij2.head(15)
# Out:
#             ENTIDAD          SERVICIO           GRUPO LINEAS_ACCESOS  \
# 0    Aguascalientes  Banda ancha fija   AMÉRICA MÓVIL        125,603
# 1    Aguascalientes  Banda ancha fija   GRUPO SALINAS         66,308
# 2    Aguascalientes  Banda ancha fija  GRUPO TELEVISA         93,827
# 3    Aguascalientes  Banda ancha fija   MEGACABLE-MCM         17,987
# 4    Aguascalientes    TV Restringida        DISH-MVS          9,039
# 5    Aguascalientes    TV Restringida   GRUPO SALINAS         39,692
# 6    Aguascalientes    TV Restringida  GRUPO TELEVISA        174,613
# 7    Aguascalientes    TV Restringida   MEGACABLE-MCM         21,429
# 8    Aguascalientes    TV Restringida       STARGROUP         21,275
# 9    Aguascalientes    Telefonía fija   AMÉRICA MÓVIL        110,654
# 10   Aguascalientes    Telefonía fija           AXTEL          2,923
# 11   Aguascalientes    Telefonía fija   GRUPO SALINAS         68,438
# 12   Aguascalientes    Telefonía fija  GRUPO TELEVISA         17,485
# ...

# %%
key_vals = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S1_KEY_VALUES.csv")
key_vals.head(15)
# Out:
#          ENT                              DIVISION             DESCRIPCION  \
# 0   Nacional  Disponibilidad de TIC en los hogares             Computadora
# 1   Nacional  Disponibilidad de TIC en los hogares                   Radio
# 2   Nacional  Disponibilidad de TIC en los hogares            TV analógica
# 3   Nacional  Disponibilidad de TIC en los hogares              TV digital
# 4   Nacional  Disponibilidad de TIC en los hogares         Telefonía móvil
# 5   Nacional      Distribución de lineas o accesos        Banda ancha fija
# 6   Nacional      Distribución de lineas o accesos                  TV RES
# 7   Nacional      Distribución de lineas o accesos          Telefonía fija
# 8   Nacional          Distribución servicios fijos           Dos servicios
# 9   Nacional          Distribución servicios fijos          Tres servicios
# 10  Nacional          Distribución servicios fijos             Un servicio
# ...

# %%
baf_x_tec = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S2_BAF_POR_TECONOLOGIA.csv")
baf_x_tec.head(15)
# Out:
#            ENTIDAD  PERIODO                  TECNOLOGIA  PORCENTAJE  ACCESOS
# 0   Aguascalientes  2013-II               Cable coaxial        4.99     5938
# 1   Aguascalientes  2013-II                         DSL       74.72    88888
# 2   Aguascalientes  2013-II                Fibra óptica        5.01     5961
# 3   Aguascalientes  2013-II  Terrestre fijo inalámbrico       15.28    18172
# 4   Aguascalientes  2013-II                       Total         NaN   118959
# 5   Aguascalientes  2013-IV               Cable coaxial        5.26     6530
# 6   Aguascalientes  2013-IV                         DSL       73.24    90980
# 7   Aguascalientes  2013-IV                Fibra óptica        5.91     7347
# 8   Aguascalientes  2013-IV  Terrestre fijo inalámbrico       15.59    19373
# 9   Aguascalientes  2013-IV                       Total         NaN   124230
# 10  Aguascalientes  2014-II               Cable coaxial        5.67     7276
# ...

# %%
tab_map_int_fij = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S3_TABLA_MAPA_INTERNET_FIJO.csv")
tab_map_int_fij.head(15)
# Out:
#                     ENT  TOP                  MUNICIPIO  ACCESOS_INTERNET_FIJO
# 0        Aguascalientes    1             Aguascalientes                     96
# 1        Aguascalientes    2                Jesús María                     63
# 2        Aguascalientes    3  San Francisco de los Romo                     40
# 3        Aguascalientes    4        Pabellón de Arteaga                     51
# 4        Aguascalientes    5            Rincón de Romos                     39
# 5       Baja California    1                    Tijuana                    109
# 6       Baja California    2                   Mexicali                     97
# 7       Baja California    3                   Ensenada                    106
# 8       Baja California    4         Playas de Rosarito                    111
# 9       Baja California    5                     Tecate                     97
# 10  Baja California Sur    1                  Los Cabos                    101
# ...

# %%
tab_map_tel_fij = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S3_TABLA_MAPA_TELEFONIA_FIJA.csv")
tab_map_tel_fij.head(15)
# Out:
#                     ENT  TOP            MUNICIPIO  LINEAS_TELEFONIA_FIJA
# 0        Aguascalientes    1       Aguascalientes                     73
# 1        Aguascalientes    2          Jesús María                     28
# 2        Aguascalientes    3             Calvillo                     30
# 3        Aguascalientes    4      Rincón de Romos                     15
# 4        Aguascalientes    5  Pabellón de Arteaga                     18
# 5       Baja California    1              Tijuana                    102
# 6       Baja California    2             Mexicali                     89
# 7       Baja California    3             Ensenada                     92
# 8       Baja California    4   Playas de Rosarito                    125
# 9       Baja California    5               Tecate                     87
# 10  Baja California Sur    1            Los Cabos                     84
# 11  Baja California Sur    2               La Paz                     83
# ...

# %%
tab_map_tvr = pd.read_csv("/home/lalo/2025-02-trabajos/datasets/TODO_ME/S3_TABLA_MAPA_TV_RESTRINGIDA.csv")
tab_map_tvr.head(15)
# Out:
#                     ENT  TOP                  MUNICIPIO  \
# 0        Aguascalientes    1             Aguascalientes
# 1        Aguascalientes    2                Jesús María
# 2        Aguascalientes    3  San Francisco de los Romo
# 3        Aguascalientes    4            Rincón de Romos
# 4        Aguascalientes    5        Pabellón de Arteaga
# 5       Baja California    1                    Tijuana
# 6       Baja California    2                   Mexicali
# 7       Baja California    3                   Ensenada
# 8       Baja California    4         Playas de Rosarito
# 9       Baja California    5                     Tecate
# 10  Baja California Sur    1                     La Paz
# 11  Baja California Sur    2                  Los Cabos
# 12  Baja California Sur    3                    Comondú
# 13  Baja California Sur    4                     Mulegé
# 14  Baja California Sur    5                     Loreto
#
#     ACCESOS_TELEVISION_RESTRINGIDA
# ...
